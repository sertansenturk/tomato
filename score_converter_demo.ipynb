# %%
from tomato.symbolic.ScoreConverter import ScoreConverter
import pprint 
import os

# %%
# score filepaths
txt_filename = os.path.join('ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede',
                            'ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.txt')
mu2_filename = os.path.join('ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede',
                            'ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.mu2')

# only needed if the filename is modified from the SymbTr naming convention
symbtr_name = 'ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede'
mbid = 'e7924b0d-c8a0-4b4a-b253-8eec898eac1e'

# instantiate analyzer object
scoreConverter = ScoreConverter()

# %% [markdown]
# You can use the single line call "convert," which does all the available conversions,
# *[txt + mu2] => MusicXML => LilyPond => svg*, simultaneously

# %% [markdown]
# ... or you can call all the methods individually.

# %%
# convert symbtr-txt file to MusicXML format. Use the metadata in the mu2 header as
# complementary information
xml_str = scoreConverter.txt_mu2_to_musicxml(txt_filename, mu2_filename, out=None,
                                             symbtr_name=symbtr_name, mbid=mbid)

# convert the MusicXML to LilyPond
ly_str, xml2ly_mapping = scoreConverter.musicxml_to_lilypond(
    xml_str, lilypond_out=None, render_metadata=True)

# convert the LilyPond to svg
svg = scoreConverter.lilypond_to_svg(ly_str, svg_out=None)

# %%
print svg
# Out:
# ['<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.2" width="203.20mm" height="127.00mm" viewBox="0 0 115.6320 72.2700">\n<!-- Page: 1/5 -->\n<text transform="translate(5.6906, 2.8453)" font-family="Century Schoolbook L" font-size="2.2001" text-anchor="start" fill="currentColor">\n<tspan>\n </tspan>\n</text>\n<text transform="translate(41.9052, 6.4402)" font-family="Century Schoolbook L" font-weight="bold" font-size="3.4927" text-anchor="start" fill="currentColor">\n<tspan>\nU\xc5\x9f\xc5\x9fak Sazsem\xc3\xa2\xc3\xaesi</tspan>\n</text>\n<text transform="translate(5.6906, 9.9402)" font-family="Century Schoolbook L" font-size="2.2001" text-anchor="start" fill="currentColor">\n<tspan>\nLyricist: -</tspan>\n</text>\n<text transform="translate(91.5723, 9.9402)" font-family="Century Schoolbook L" font-size="2.2001" text-anchor="start" fill="currentColor">\n<tspan>\nNeyzen Aziz Dede</tspan>\n</text>\n<text transform="translate(5.6906, 12.5229)" font-family="Century Schoolbook L" font-size="2.2001" text-anchor="start" fill="currentColor">\n<tspan>\nMakam: Sazsem\xc3\xa2\xc3\xaesi, Form: U\xc5\x9f\xc5\x9fak, Usul: Aksaksem\xc3\xa2\xc3\xae</tspan>\n</text>\n<line transform="translate(14.2264, 20.6339)" stroke-linejoin="round" stroke-linecap="round" stroke-width="0.1000" stroke="currentColor" x1="0.0500" y1="-0.0000" x2="95.6651" y2="-0.0000"/>\n<line transform="translate(14.2264, 19.6339)" stroke-linejoin="round" stroke-linecap="round" stroke-width="0.1000" stroke="currentColor" x1="0.0500" y1="-0.0000" x2="95.6651" y2="-0.0000"/>\n<line transform="translate(14.2264, 18.6339)" stroke-linejoin="round" stroke-linecap="round" stroke-width="0.1000" stroke="currentColor" x1="0.0500" y1="-0.0000" x2="95.6651" y2="-0.0000"/>\n<line transform="translate(14.2264, 17.6339)" stroke-linejoin="round" stroke-linecap="round" stroke-width="0.1000" stroke="currentColor" x1="0.0500" y1="-0.0000" x2="95.6651" y2="-0.0000"/>\n<line transform="translate(14.2264, 16.6339)" stroke-linejoin="round" stroke-linecap="round" stroke-width="0.1000" stroke="currentColor" x1="0.0500" y1="-0.0000" x2="95.6651" y2="-0.0000"/>\n<rect transform="translate(109.7514, 18.6339)" x="0.0000" y="-2.0000" width="0.1900" height="4.0000" ry="0.0000" fill="currentColor"/>\n<rect transform="translate(69.8819, 18.6339)" x="0.0000" y="-2.0000" width="0.1900" height="4.0000" ry="0.0000" fill="currentColor"/>\n<path transform="translate(76.3798, 21.5939) scale(0.0040, -0.0040)" d="M0 0h-16v250h16c98 58 227 148 227 259c0 57 -16 112 -41 163c-3 16 10 27 23 27c7 0 15 -3 20 -11c25 -56 40 -117 40 -179c0 -204 -269 -305 -269 -509z" fill="currentColor"/>\n<a style="color:inherit;" id="l43-f2-t17" from="2" to="17">\n<path transform="translate(80.0851, 18.6339) scale(0.0040, -0.0040)" d="M220 138c56 0 109 -29 109 -91c0 -72 -56 -121 -103 -149c-36 -21 -76 -36 -117 -36c-56 0 -109 29 -109 91c0 72 56 121 103 149c36 21 76 36 117 36z" fill="currentColor"/>\n</a>\n<path transform="translate(81.8513, 18.1339) scale(0.0040, -0.0040)" d="M0 0c0 31 25 56 56 56s56 -25 56 -56s-25 -56 -56 -56s-56 25 -56 56z" fill="currentColor"/>\n<rect transform="translate(80.1501, 18.6339)" x="-0.0650" y="0.1878" width="0.1300" height="3.8106" ry="0.0400" fill="currentColor"/>\n<a style="color:inherit;" id="l44-f2-t17" from="2" to="17">\n<path transform="translate(83.3977, 19.1339) scale(0.0040, -0.0040)" d="M220 138c56 0 109 -29 109 -91c0 -72 -56 -121 -103 -149c-36 -21 -76 -36 -117 -36c-56 0 -109 29 -109 91c0 72 56 121 103 149c36 21 76 36 117 36z" fill="currentColor"/>\n</a>\n<rect transform="translate(83.4627, 18.6339)" x="-0.0650" y="0.6878" width="0.1300" height="3.2316" ry="0.0400" fill="currentColor"/>\n<a style="color:inherit;" id="l45-f2-t17" from="2" to="17">\n<path transform="translate(85.3436, 18.6339) scale(0.0040, -0.0040)" d="M220 138c56 0 109 -29 109 -91c0 -72 -56 -121 -103 -149c-36 -21 -76 -36 -117 -36c-56 0 -109 29 -109 91c0 72 56 121 103 149c36 21 76 36 117 36z" fil ...
