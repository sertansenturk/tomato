# %%
from tomato.symbolic.SymbTrAnalyzer import SymbTrAnalyzer
from symbtrextras.ScoreExtras import ScoreExtras
import os
from pprint import pprint

# %%
# score filepaths
txt_filepath = os.path.join('ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede',
                            'ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.txt')
mu2_filepath = os.path.join('ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede',
                            'ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.mu2')
save_filepath = os.path.join('ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede',
                             'ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.pkl')

# only needed if the filename is modified from the SymbTr naming convention
symbtr_name = 'ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede'

# instantiate analyzer object
scoreAnalyzer = SymbTrAnalyzer(verbose=True)

# %% [markdown]
# You can use the single line call "analyze," which does all the available analysis simultaneously

# %%
score_data = scoreAnalyzer.analyze(txt_filepath, mu2_filepath, symbtr_name=symbtr_name)
# Out:
# - Automatic phrase segmentation on the SymbTr-txt file: ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede/ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.txt
#   The call took 9.16 seconds to execute.
# - Extracting (meta)data from the SymbTr-txt file: ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede/ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.txt
#   The call took 0.61 seconds to execute.
# - Extracting metadata from the SymbTr-mu2 file: ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede/ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.mu2
#   The call took 0.01 seconds to execute.

# %% [markdown]
# ... or you can call all the methods individually
#
# **Note:** If you want to call the extractors for each score format individualy, please use the **symbtrdataextractor** package. You can refer to the [extractsymbtrdata.ipynb](https://github.com/sertansenturk/symbtrdataextractor/blob/master/extractsymbtrdata.ipynb) for an interactive demo

# %%
# Automatic phrase segmentation on the SymbTr-txt score using pre-trained model
phrase_bounds = scoreAnalyzer.segment_phrase(txt_filepath, symbtr_name=symbtr_name)

# relevant recording or work mbid, if you want additional information from musicbrainz
# Note 1: MBID input will make the function returns significantly slower because we
#         have to wait a couple of seconds before each subsequent query from MusicBrainz.
# Note 2: very rare but there can be more that one mbid returned. We are going to use 
#         the first work to get fetch the metadata
mbid = ScoreExtras.get_mbids(symbtr_name)[0]

# Extract the (meta)data from the SymbTr scores
# This includes the metadata from the score formats and MusicBrainz, extracted sections
# rhythmic structure etc.
score_data = scoreAnalyzer.extract_data(
    txt_filepath, mu2_filepath, symbtr_name=symbtr_name, mbid=mbid, 
    segment_note_bound_idx=phrase_bounds['boundary_note_idx'])
# Out:
# - Automatic phrase segmentation on the SymbTr-txt file: ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede/ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.txt
#   The call took 8.54 seconds to execute.
# - Extracting (meta)data from the SymbTr-txt file: ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede/ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.txt
#   The call took 0.63 seconds to execute.
# - Extracting metadata from the SymbTr-mu2 file: ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede/ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede.mu2
#   The call took 0.01 seconds to execute.

# %%
# pretty print the data
pprint(score_data)
# Out:
# ({'composer': {'mbid': 'a6775723-69b6-4997-82da-bf230b1f8655',
#                'mu2_name': u'Neyzen Aziz Dede',
#                'name': 'Neyzen Aziz Dede',
#                'symbtr_slug': 'neyzen_aziz_dede'},
#   'duration': {'unit': 'second', 'value': 275.821},
#   'form': {'attribute_key': u'sazsemaisi',
#            'mb_attribute': 'Sazsemaisi',
#            'mu2_name': u'Sazsem\xe2\xeesi',
#            'source': u'http://musicbrainz.org/work/e7924b0d-c8a0-4b4a-b253-8eec898eac1e',
#            'symbtr_slug': 'sazsemaisi'},
#   'genre': 'classical',
#   'key_signature': [u'B4b2'],
#   'language': 'zxx',
#   'lyricist': {'mu2_name': u'-'},
#   'makam': {'attribute_key': u'ussak',
#             'mb_attribute': u'U\u015f\u015fak',
#             'mu2_name': u'U\u015f\u015fak',
#             'source': u'http://musicbrainz.org/work/e7924b0d-c8a0-4b4a-b253-8eec898eac1e',
#             'symbtr_slug': 'ussak'},
#   'notation': u'TSM',
#   'number_of_notes': 680,
#   'phrase_annotations': [],
#   'recordings': [],
#   'rhythmic_structure': [{'endNote': 478,
#                           'startNote': 1,
#                           'tempo': {'unit': 'bpm', 'value': 112},
#                           'usul': {'attribute_key': u'aksaksemai',
#                                    'mertebe': 8,
#                                    'mu2_name': u'Aksaksem\xe2\xee',
#                                    'number_of_pulses': 10,
#                                    'symbtr_internal_id': 30}},
#                          {'endNote': 573,
#                           'startNote': 479,
#                           'tempo': {'unit': 'bpm', 'value': 54},
#                           'usul': {'attribute_key': u'yuruksemai_ii',
#                                    'mertebe': 8,
#                                    'mu2_name': u'Y\xfcr\xfcksem\xe2\xee II',
#                                    'number_of_pulses': 6,
#                                    'symbtr_internal_id': 87}},
#                          {'endNote': 680,
#                           'startNote': 574,
#                           'tempo': {'unit': 'bpm', 'value': 28},
#                           'usul': {'attribute_key': u'aksaksemai',
#                                    'mertebe': 8,
#                                    'mu2_name': u'Aksaksem\xe2\xee',
#                                    'number_of_pulses': 10,
#                                    'symbtr_internal_id': 30}}],
#   'scores': [u'ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede'],
#   'sections': [{'end_note': 56,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'1-HANE_1',
#                 'name': u'1. HANE',
#                 'slug': u'1-HANE',
#                 'start_note': 2},
#                {'end_note': 109,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'TESLIM_1',
#                 'name': u'TESL\u0130M',
#                 'slug': u'TESLIM',
#                 'start_note': 57},
#                {'end_note': 162,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'TESLIM_1',
#                 'name': u'TESL\u0130M',
#                 'slug': u'TESLIM',
#                 'start_note': 110},
#                {'end_note': 211,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'2-HANE_1',
#                 'name': u'2. HANE',
#                 'slug': u'2-HANE',
#                 'start_note': 163},
#                {'end_note': 264,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'TESLIM_1',
#                 'name': u'TESL\u0130M',
#                 'slug': u'TESLIM',
#                 'start_note': 212},
#                {'end_note': 317,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'TESLIM_1',
#                 'name': u'TESL\u0130M',
#                 'slug': u'TESLIM',
#                 'start_note': 265},
#                {'end_note': 372,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'3-HANE_1',
#                 'name': u'3. HANE',
#                 'slug': u'3-HANE',
#                 'start_note': 318},
#                {'end_note': 425,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'TESLIM_1',
#                 'name': u'TESL\u0130M',
#                 'slug': u'TESLIM',
#                 'start_note': 373},
#                {'end_note': 479,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'TESLIM_1',
#                 'name': u'TESL\u0130M',
#                 'slug': u'TESLIM',
#                 'start_note': 426},
#                {'end_note': 526,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'4-HANE_1',
#                 'name': u'4. HANE',
#                 'slug': u'4-HANE',
#                 'start_note': 480},
#                {'end_note': 574,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'4-HANE_1',
#                 'name': u'4. HANE',
#                 'slug': u'4-HANE',
#                 'start_note': 527},
#                {'end_note': 627,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'TESLIM_1',
#                 'name': u'TESL\u0130M',
#                 'slug': u'TESLIM',
#                 'start_note': 575},
#                {'end_note': 680,
#                 'lyric_structure': 'INSTRUMENTAL',
#                 'lyrics': '',
#                 'melodic_structure': u'TESLIM_1',
#                 'name': u'TESL\u0130M',
#                 'slug': u'TESLIM',
#                 'start_note': 628}],
#   'segmentations': [{'end_note': 28,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'A1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'1-HANE_1',
#                                    'section_idx': 0}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 2},
#                     {'end_note': 41,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'B1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'1-HANE_1',
#                                    'section_idx': 0}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 29},
#                     {'end_note': 57,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'C1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'1-HANE_1',
#                                    'section_idx': 0},
#                                   {'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 1}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 42},
#                     {'end_note': 77,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'D1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 1}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 58},
#                     {'end_note': 96,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'E1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 1}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 78},
#                     {'end_note': 110,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'CF1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 1},
#                                   {'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 2}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 97},
#                     {'end_note': 130,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'D1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 2}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 111},
#                     {'end_note': 149,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'E1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 2}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 131},
#                     {'end_note': 162,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'F1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 2}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 150},
#                     {'end_note': 172,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'G1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'2-HANE_1',
#                                    'section_idx': 3}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 163},
#                     {'end_note': 184,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'H1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'2-HANE_1',
#                                    'section_idx': 3}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 173},
#                     {'end_note': 199,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'I1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'2-HANE_1',
#                                    'section_idx': 3}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 185},
#                     {'end_note': 212,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'F2',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'2-HANE_1',
#                                    'section_idx': 3},
#                                   {'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 4}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 200},
#                     {'end_note': 232,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'D1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 4}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 213},
#                     {'end_note': 251,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'E1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 4}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 233},
#                     {'end_note': 265,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'CF1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 4},
#                                   {'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 5}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 252},
#                     {'end_note': 285,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'D1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 5}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 266},
#                     {'end_note': 304,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'E1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 5}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 286},
#                     {'end_note': 317,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'F1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 5}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 305},
#                     {'end_note': 373,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'J1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'3-HANE_1',
#                                    'section_idx': 6},
#                                   {'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 7}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 318},
#                     {'end_note': 393,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'D1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 7}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 374},
#                     {'end_note': 412,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'E1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 7}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 394},
#                     {'end_note': 426,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'CF1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 7},
#                                   {'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 8}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 413},
#                     {'end_note': 446,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'D1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 8}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 427},
#                     {'end_note': 465,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'E1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 8}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 447},
#                     {'end_note': 480,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'CF1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 8},
#                                   {'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 9}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 466},
#                     {'end_note': 490,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'K1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 9}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 481},
#                     {'end_note': 502,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'L1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 9}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 491},
#                     {'end_note': 512,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'M1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 9}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 503},
#                     {'end_note': 526,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'N1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 9}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 513},
#                     {'end_note': 531,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'O1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 10}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 527},
#                     {'end_note': 536,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'P1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 10}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 532},
#                     {'end_note': 549,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'L2',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 10}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 537},
#                     {'end_note': 556,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'M2',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 10}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 550},
#                     {'end_note': 566,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'Q1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 10}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 557},
#                     {'end_note': 574,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'R1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'4-HANE_1',
#                                    'section_idx': 10}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 567},
#                     {'end_note': 579,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'S1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 11}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 575},
#                     {'end_note': 595,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'D2',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 11}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 580},
#                     {'end_note': 632,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'T1',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 11},
#                                   {'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 12}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 596},
#                     {'end_note': 648,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'D2',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 12}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 633},
#                     {'end_note': 680,
#                      'flavor': [],
#                      'lyric_structure': 'INSTRUMENTAL',
#                      'lyrics': '',
#                      'melodic_structure': u'T2',
#                      'name': u'INSTRUMENTAL_SEGMENT',
#                      'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                    'melodic_structure': u'TESLIM_1',
#                                    'section_idx': 12}],
#                      'slug': u'INSTRUMENTAL_SEGMENT',
#                      'start_note': 649}],
#   'symbtr': 'ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede',
#   'tempo': {'unit': 'bpm', 'value': 112},
#   'tonic': u'A4',
#   'usul': {'attribute_key': u'aksaksemai',
#            'mb_attribute': 'Aksaksemai',
#            'mertebe': 8,
#            'mu2_name': u'Aksaksem\xe2\xee',
#            'number_of_pulses': 10,
#            'source': u'http://musicbrainz.org/work/e7924b0d-c8a0-4b4a-b253-8eec898eac1e',
#            'symbtr_slug': 'aksaksemai'},
#   'work': {'mbid': u'e7924b0d-c8a0-4b4a-b253-8eec898eac1e',
#            'mu2_title': u'U\u015f\u015fak Sazsem\xe2\xeesi',
#            'symbtr_slug': '',
#            'title': u'U\u015f\u015fak Saz Semaisi'}},
#  {'is_all_valid': True, 'is_mu2_header_valid': True, 'is_txt_valid': True})
